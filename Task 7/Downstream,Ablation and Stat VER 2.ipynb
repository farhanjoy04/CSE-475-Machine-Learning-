# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
import tensorflow.keras.backend as K


# --------------------------------------------------------
# 1️⃣ Define Custom L2 Normalization Layer
# --------------------------------------------------------
class L2Normalization(Layer):
    def __init__(self, axis=-1, **kwargs):
        super(L2Normalization, self).__init__(**kwargs)
        self.axis = axis

    def call(self, inputs):
        return tf.nn.l2_normalize(inputs, axis=self.axis)

    def get_config(self):
        config = super().get_config()
        config.update({"axis": self.axis})
        return config


# OPTIONAL: If your models include projection head or stop-gradient functions
# you can define placeholders (they are often identity layers in SSL)

class IdentityLayer(Layer):
    def call(self, x):
        return x


custom_objects = {
    "L2Normalization": L2Normalization,
    "IdentityLayer": IdentityLayer,
}
# Out:
# 2025-12-14 10:28:56.540213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765708136.748821      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765708136.799155      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
import os

base_dir = "/kaggle/input/alzeihmer-disease-model/other/default/1"

simclr_path = os.path.join(base_dir, "alzheimer_ssl_2 SimCLRmodel.h5")
simsam_path = os.path.join(base_dir, "alzheimer_ssl_3 -Simsiammodel.h5")
barlow_path = os.path.join(base_dir, "alzheimer_ssl_4- Barlow twinsmodel.h5")

print("Loading SSL Models with custom layers...")

simclr_model = tf.keras.models.load_model(simclr_path, custom_objects=custom_objects)
simsam_model = tf.keras.models.load_model(simsam_path, custom_objects=custom_objects)
barlow_model = tf.keras.models.load_model(barlow_path, custom_objects=custom_objects)

print("✅ All SSL models loaded successfully!")
# Out:
# Loading SSL Models with custom layers...
# I0000 00:00:1765708153.588559      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ All SSL models loaded successfully!

# %%
#Setup + paths (auto-detect train/test folders)
import os, glob, json, math, random
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("TF:", tf.__version__)
# Out:
# TF: 2.18.0

# %%
# ========= USER PATHS =========
SSL_BASE_DIR = "/kaggle/input/alzeihmer-disease-model/other/default/1"
DATASET_ROOT = "/kaggle/input/alzheimer-disease"

simclr_path  = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_2 SimCLRmodel.h5")
simsam_path  = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_3 -Simsiammodel.h5")
barlow_path  = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_4- Barlow twinsmodel.h5")

print("SSL model paths:")
print(simclr_path)
print(simsam_path)
print(barlow_path)

# ========= AUTO-FIND train/test directories =========
CLASSES = ["AD", "CN", "MCI"]  # keep your order consistent everywhere

def find_split_dir(root, split_name="train"):
    """
    Finds a directory that contains subfolder `split_name` and inside it the class folders.
    Works for structures like:
      /kaggle/input/alzheimer-disease/train-.../train/AD ...
      /kaggle/input/alzheimer-disease/test-.../test/AD ...
    """
    candidates = []
    for dirpath, dirnames, filenames in os.walk(root):
        base = os.path.basename(dirpath).lower()
        if base == split_name.lower():
            # check classes exist
            ok = all(os.path.isdir(os.path.join(dirpath, c)) for c in CLASSES)
            if ok:
                candidates.append(dirpath)
    # pick shortest (closest to root) if multiple
    candidates = sorted(candidates, key=lambda p: len(p))
    return candidates[0] if candidates else None

train_dir = find_split_dir(DATASET_ROOT, "train")
test_dir  = find_split_dir(DATASET_ROOT, "test")

print("Resolved train_dir:", train_dir)
print("Resolved test_dir :", test_dir)

assert train_dir is not None, "Could not find a valid train/ directory containing AD,CN,MCI."
assert test_dir  is not None, "Could not find a valid test/ directory containing AD,CN,MCI."
# Out:
# SSL model paths:
# /kaggle/input/alzeihmer-disease-model/other/default/1/alzheimer_ssl_2 SimCLRmodel.h5
# /kaggle/input/alzeihmer-disease-model/other/default/1/alzheimer_ssl_3 -Simsiammodel.h5
# /kaggle/input/alzeihmer-disease-model/other/default/1/alzheimer_ssl_4- Barlow twinsmodel.h5
# Resolved train_dir: /kaggle/input/alzheimer-disease/train-20251010T183510Z-1-001/train
# Resolved test_dir : /kaggle/input/alzheimer-disease/test-20251010T094612Z-1-001/test

# %%
#Data loaders (train/val/test) – stable & reproducible
IMG_SIZE = (224, 224)  
BATCH_SIZE = 32

def make_ds(directory, shuffle=True):
    ds = tf.keras.utils.image_dataset_from_directory(
        directory,
        labels="inferred",
        label_mode="int",
        class_names=CLASSES,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        seed=SEED
    )
    return ds

train_full = make_ds(train_dir, shuffle=True)
test_ds    = make_ds(test_dir, shuffle=False)

# split train -> train/val
VAL_FRAC = 0.2
card = tf.data.experimental.cardinality(train_full).numpy()
val_batches = max(1, int(card * VAL_FRAC))
train_batches = card - val_batches

val_ds   = train_full.take(val_batches)
train_ds = train_full.skip(val_batches)

print("Batches - train:", tf.data.experimental.cardinality(train_ds).numpy(),
      "val:", tf.data.experimental.cardinality(val_ds).numpy(),
      "test:", tf.data.experimental.cardinality(test_ds).numpy())

# normalization (0..1)
norm = layers.Rescaling(1./255)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x,y: (norm(x), y), num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds   = val_ds.map(lambda x,y: (norm(x), y), num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
test_ds  = test_ds.map(lambda x,y: (norm(x), y), num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
# Out:
# Found 4123 files belonging to 3 classes.
# Found 1031 files belonging to 3 classes.
# Batches - train: 104 val: 25 test: 33

# %%
#Defining the L2 Normalization
import tensorflow as tf
from tensorflow import keras

@keras.utils.register_keras_serializable(package="Custom")
class L2Normalization(keras.layers.Layer):
    def __init__(self, axis=-1, epsilon=1e-12, **kwargs):
        super().__init__(**kwargs)
        self.axis = axis
        self.epsilon = epsilon

    def call(self, inputs):
        return tf.nn.l2_normalize(inputs, axis=self.axis, epsilon=self.epsilon)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"axis": self.axis, "epsilon": self.epsilon})
        return cfg

# %%
#Loading Models 
import os
import tensorflow as tf

SSL_BASE_DIR = "/kaggle/input/alzeihmer-disease-model/other/default/1"

simclr_path = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_2 SimCLRmodel.h5")
simsam_path = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_3 -Simsiammodel.h5")
barlow_path = os.path.join(SSL_BASE_DIR, "alzheimer_ssl_4- Barlow twinsmodel.h5")

custom_objects = {
    "L2Normalization": L2Normalization,
}

print("Loading SSL Models with custom_object_scope...")

with keras.utils.custom_object_scope(custom_objects):
    simclr_model = tf.keras.models.load_model(simclr_path, compile=False)
    simsam_model = tf.keras.models.load_model(simsam_path, compile=False)
    barlow_model = tf.keras.models.load_model(barlow_path, compile=False)

print(" All SSL models loaded successfully!")
# Out:
# Loading SSL Models with custom_object_scope...
#  All SSL models loaded successfully!

# %%
#Build Encoders from SSL Models
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def make_encoder(ssl_model):
    """
    Robustly extracts an encoder from an SSL model.
    Priority:
    1. Known encoder/backbone layer names
    2. Second last layer (typical SSL practice)
    """
    preferred_names = [
        "encoder", "backbone", "base_encoder",
        "feature_extractor", "resnet", "convnext"
    ]

    for name in preferred_names:
        try:
            layer = ssl_model.get_layer(name)
            print(f"Using encoder layer: {name}")
            return keras.Model(
                inputs=ssl_model.input,
                outputs=layer.output,
                name=f"{ssl_model.name}_{name}"
            )
        except:
            pass

    # Fallback → second last layer
    print(" Encoder not explicitly found → using fallback (2nd last layer)")
    output = ssl_model.layers[-2].output
    return keras.Model(
        inputs=ssl_model.input,
        outputs=output,
        name=f"{ssl_model.name}_encoder_fallback"
    )


enc_simclr  = make_encoder(simclr_model)
enc_simsam  = make_encoder(simsam_model)
enc_barlow  = make_encoder(barlow_model)

print("Encoder outputs:")
print("SimCLR :", enc_simclr.output_shape)
print("SimSiam:", enc_simsam.output_shape)
print("Barlow :", enc_barlow.output_shape)
# Out:
#  Encoder not explicitly found → using fallback (2nd last layer)
#  Encoder not explicitly found → using fallback (2nd last layer)
#  Encoder not explicitly found → using fallback (2nd last layer)
# Encoder outputs:
# SimCLR : (None, 256)
# SimSiam: (None, 256)
# Barlow : (None, 256)

# %%
#Dataset Pipeline (Train / Val / Test)
import numpy as np

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

CLASSES = ["AD", "CN", "MCI"]

train_ds_full = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_names=CLASSES,
    label_mode="int",
    shuffle=True,
    seed=SEED
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_names=CLASSES,
    label_mode="int",
    shuffle=False
)

# Train/Val split
val_fraction = 0.2
total_batches = tf.data.experimental.cardinality(train_ds_full).numpy()
val_batches = int(total_batches * val_fraction)

val_ds   = train_ds_full.take(val_batches)
train_ds = train_ds_full.skip(val_batches)

# Normalization
normalizer = layers.Rescaling(1./255)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x,y: (normalizer(x), y)).prefetch(AUTOTUNE)
val_ds   = val_ds.map(lambda x,y: (normalizer(x), y)).prefetch(AUTOTUNE)
test_ds  = test_ds.map(lambda x,y: (normalizer(x), y)).prefetch(AUTOTUNE)

print("Dataset ready ")
# Out:
# Found 4123 files belonging to 3 classes.
# Found 1031 files belonging to 3 classes.
# Dataset ready

# %%
#LARS Optimizer (Safe Fallback)
def get_optimizer(name="lars", lr=1e-3):
    name = name.lower()
    if name == "lars":
        try:
            import tensorflow_addons as tfa
            print("Using LARS optimizer")
            return tfa.optimizers.LARS(learning_rate=lr, momentum=0.9)
        except:
            print(" LARS unavailable → falling back to Adam")
            return keras.optimizers.Adam(learning_rate=lr)
    elif name == "sgd":
        return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    else:
        return keras.optimizers.Adam(learning_rate=lr)

# %%
#Downstream Classifier Head
NUM_CLASSES = len(CLASSES)

def build_downstream_model(encoder, trainable=False, dropout=0.3):
    encoder.trainable = trainable

    inputs = keras.Input(shape=(*IMG_SIZE, 3))
    x = encoder(inputs)

    # Handle spatial / vector outputs
    if len(x.shape) == 4:
        x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

    model = keras.Model(inputs, outputs, name=f"downstream_{encoder.name}")
    return model

# %%
#Train Downstream Models (SimCLR / SimSiam / Barlow)
EPOCHS = 30
LR = 1e-3
OPT = "lars"

models = {}
histories = {}

for name, encoder in {
    "SimCLR": enc_simclr,
    "SimSiam": enc_simsam,
    "BarlowTwins": enc_barlow
}.items():

    print(f"\n==== Training downstream: {name} ====")

    model = build_downstream_model(encoder, trainable=False)

    model.compile(
        optimizer=get_optimizer(OPT, LR),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    callbacks = [
        keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(patience=2)
    ]

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )

    models[name] = model
    histories[name] = history
# Out:
# ==== Training downstream: SimCLR ====
#  LARS unavailable → falling back to Adam
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765708206.556480      58 service.cc:148] XLA service 0x794f60002fa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765708206.557247      58 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1765708211.541247      58 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 1:42:57 60s/step - accuracy: 0.3438 - loss: 1.1692
# I0000 00:00:1765708234.208400      58 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 106s 444ms/step - accuracy: 0.4454 - loss: 1.1710 - val_accuracy: 0.4675 - val_loss: 1.0726 - learning_rate: 0.0010
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.4918 - loss: 1.0531 - val_accuracy: 0.3787 - val_loss: 1.1101 - learning_rate: 0.0010
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4870 - loss: 1.0487 - val_accuracy: 0.4888 - val_loss: 1.0531 - learning_rate: 0.0010
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4986 - loss: 1.0223 - val_accuracy: 0.2575 - val_loss: 1.3110 - learning_rate: 0.0010
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4867 - loss: 1.0310 - val_accuracy: 0.4625 - val_loss: 1.0467 - learning_rate: 0.0010
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5261 - loss: 0.9998 - val_accuracy: 0.3175 - val_loss: 1.2172 - learning_rate: 0.0010
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.5899 - loss: 0.8882 - val_accuracy: 0.5150 - val_loss: 0.9796 - learning_rate: 0.0010
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5786 - loss: 0.9165 - val_accuracy: 0.4288 - val_loss: 1.0319 - learning_rate: 0.0010
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6592 - loss: 0.7498 - val_accuracy: 0.4837 - val_loss: 1.2313 - learning_rate: 0.0010
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.7159 - loss: 0.6455 - val_accuracy: 0.7175 - val_loss: 0.6926 - learning_rate: 1.0000e-04
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.8249 - loss: 0.4462 - val_accuracy: 0.8375 - val_loss: 0.3805 - learning_rate: 1.0000e-04
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.8821 - loss: 0.3465 - val_accuracy: 0.9237 - val_loss: 0.2451 - learning_rate: 1.0000e-04
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9221 - loss: 0.2376 - val_accuracy: 0.8750 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9307 - loss: 0.2061 - val_accuracy: 0.9137 - val_loss: 0.2792 - learning_rate: 1.0000e-04
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9373 - loss: 0.1836 - val_accuracy: 0.9613 - val_loss: 0.1408 - learning_rate: 1.0000e-05
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9527 - loss: 0.1529 - val_accuracy: 0.9638 - val_loss: 0.1335 - learning_rate: 1.0000e-05
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9599 - loss: 0.1449 - val_accuracy: 0.9650 - val_loss: 0.1180 - learning_rate: 1.0000e-05
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9623 - loss: 0.1365 - val_accuracy: 0.9712 - val_loss: 0.1096 - learning_rate: 1.0000e-05
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9638 - loss: 0.1138 - val_accuracy: 0.9675 - val_loss: 0.1120 - learning_rate: 1.0000e-05
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9578 - loss: 0.1382 - val_accuracy: 0.9675 - val_loss: 0.1104 - learning_rate: 1.0000e-05
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9736 - loss: 0.0933 - val_accuracy: 0.9675 - val_loss: 0.1172 - learning_rate: 1.0000e-06
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9669 - loss: 0.1199 - val_accuracy: 0.9675 - val_loss: 0.1080 - learning_rate: 1.0000e-06
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9746 - loss: 0.0951 - val_accuracy: 0.9712 - val_loss: 0.1044 - learning_rate: 1.0000e-06
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9774 - loss: 0.0876 - val_accuracy: 0.9675 - val_loss: 0.1093 - learning_rate: 1.0000e-06
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9532 - loss: 0.1520 - val_accuracy: 0.9688 - val_loss: 0.1099 - learning_rate: 1.0000e-06
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9731 - loss: 0.0976 - val_accuracy: 0.9688 - val_loss: 0.1035 - learning_rate: 1.0000e-07
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9614 - loss: 0.1226 - val_accuracy: 0.9688 - val_loss: 0.1046 - learning_rate: 1.0000e-07
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9581 - loss: 0.1311 - val_accuracy: 0.9700 - val_loss: 0.1000 - learning_rate: 1.0000e-07
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9773 - loss: 0.0857 - val_accuracy: 0.9712 - val_loss: 0.1030 - learning_rate: 1.0000e-07
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9790 - loss: 0.0960 - val_accuracy: 0.9762 - val_loss: 0.0918 - learning_rate: 1.0000e-07
#
# ==== Training downstream: SimSiam ====
#  LARS unavailable → falling back to Adam
# Epoch 1/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 91s 388ms/step - accuracy: 0.4255 - loss: 1.2587 - val_accuracy: 0.2725 - val_loss: 1.7124 - learning_rate: 0.0010
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4880 - loss: 1.1111 - val_accuracy: 0.4863 - val_loss: 1.0925 - learning_rate: 0.0010
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4706 - loss: 1.0712 - val_accuracy: 0.2788 - val_loss: 1.1073 - learning_rate: 0.0010
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4961 - loss: 1.0330 - val_accuracy: 0.4888 - val_loss: 1.0753 - learning_rate: 0.0010
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5032 - loss: 0.9867 - val_accuracy: 0.4512 - val_loss: 0.9851 - learning_rate: 0.0010
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5137 - loss: 0.9565 - val_accuracy: 0.5000 - val_loss: 1.1110 - learning_rate: 0.0010
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5548 - loss: 0.8973 - val_accuracy: 0.5275 - val_loss: 1.4557 - learning_rate: 0.0010
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.6186 - loss: 0.8015 - val_accuracy: 0.5437 - val_loss: 1.2380 - learning_rate: 1.0000e-04
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.6995 - loss: 0.6814 - val_accuracy: 0.6438 - val_loss: 0.8294 - learning_rate: 1.0000e-04
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.7169 - loss: 0.6360 - val_accuracy: 0.6675 - val_loss: 0.7771 - learning_rate: 1.0000e-04
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.7986 - loss: 0.4896 - val_accuracy: 0.6812 - val_loss: 0.8825 - learning_rate: 1.0000e-04
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8223 - loss: 0.4335 - val_accuracy: 0.8050 - val_loss: 0.5389 - learning_rate: 1.0000e-04
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8540 - loss: 0.3982 - val_accuracy: 0.8925 - val_loss: 0.2995 - learning_rate: 1.0000e-04
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8726 - loss: 0.3311 - val_accuracy: 0.8975 - val_loss: 0.2431 - learning_rate: 1.0000e-04
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8911 - loss: 0.2689 - val_accuracy: 0.9375 - val_loss: 0.1833 - learning_rate: 1.0000e-04
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9204 - loss: 0.2135 - val_accuracy: 0.9225 - val_loss: 0.1993 - learning_rate: 1.0000e-04
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9197 - loss: 0.1951 - val_accuracy: 0.9137 - val_loss: 0.2420 - learning_rate: 1.0000e-04
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9363 - loss: 0.1668 - val_accuracy: 0.9563 - val_loss: 0.1091 - learning_rate: 1.0000e-05
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9383 - loss: 0.1518 - val_accuracy: 0.9575 - val_loss: 0.1019 - learning_rate: 1.0000e-05
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9459 - loss: 0.1384 - val_accuracy: 0.9675 - val_loss: 0.0887 - learning_rate: 1.0000e-05
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9528 - loss: 0.1218 - val_accuracy: 0.9700 - val_loss: 0.0835 - learning_rate: 1.0000e-05
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9536 - loss: 0.1178 - val_accuracy: 0.9638 - val_loss: 0.0885 - learning_rate: 1.0000e-05
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9621 - loss: 0.1010 - val_accuracy: 0.9638 - val_loss: 0.0793 - learning_rate: 1.0000e-05
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9578 - loss: 0.1145 - val_accuracy: 0.9638 - val_loss: 0.0878 - learning_rate: 1.0000e-05
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9555 - loss: 0.1104 - val_accuracy: 0.9650 - val_loss: 0.0825 - learning_rate: 1.0000e-05
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9662 - loss: 0.0974 - val_accuracy: 0.9638 - val_loss: 0.0788 - learning_rate: 1.0000e-06
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9592 - loss: 0.1158 - val_accuracy: 0.9625 - val_loss: 0.0840 - learning_rate: 1.0000e-06
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9620 - loss: 0.0982 - val_accuracy: 0.9638 - val_loss: 0.0839 - learning_rate: 1.0000e-06
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9551 - loss: 0.1175 - val_accuracy: 0.9613 - val_loss: 0.0854 - learning_rate: 1.0000e-07
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9657 - loss: 0.1009 - val_accuracy: 0.9600 - val_loss: 0.0916 - learning_rate: 1.0000e-07
#
# ==== Training downstream: BarlowTwins ====
#  LARS unavailable → falling back to Adam
# Epoch 1/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 89s 379ms/step - accuracy: 0.4479 - loss: 1.2033 - val_accuracy: 0.2537 - val_loss: 1.1723 - learning_rate: 0.0010
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4511 - loss: 1.1123 - val_accuracy: 0.4812 - val_loss: 1.2244 - learning_rate: 0.0010
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.4769 - loss: 1.0675 - val_accuracy: 0.4787 - val_loss: 1.0526 - learning_rate: 0.0010
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4874 - loss: 1.0403 - val_accuracy: 0.4700 - val_loss: 1.0672 - learning_rate: 0.0010
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4941 - loss: 1.0099 - val_accuracy: 0.3800 - val_loss: 1.0732 - learning_rate: 0.0010
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5097 - loss: 0.9823 - val_accuracy: 0.4850 - val_loss: 1.0056 - learning_rate: 1.0000e-04
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5214 - loss: 0.9479 - val_accuracy: 0.4900 - val_loss: 0.9726 - learning_rate: 1.0000e-04
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5339 - loss: 0.9501 - val_accuracy: 0.5150 - val_loss: 0.9406 - learning_rate: 1.0000e-04
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5385 - loss: 0.9406 - val_accuracy: 0.5250 - val_loss: 0.9135 - learning_rate: 1.0000e-04
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5475 - loss: 0.9230 - val_accuracy: 0.5150 - val_loss: 0.9786 - learning_rate: 1.0000e-04
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5470 - loss: 0.8912 - val_accuracy: 0.5375 - val_loss: 1.0638 - learning_rate: 1.0000e-04
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5548 - loss: 0.8953 - val_accuracy: 0.5650 - val_loss: 0.8764 - learning_rate: 1.0000e-05
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5468 - loss: 0.8691 - val_accuracy: 0.5663 - val_loss: 0.8507 - learning_rate: 1.0000e-05
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5722 - loss: 0.8534 - val_accuracy: 0.5775 - val_loss: 0.8482 - learning_rate: 1.0000e-05
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5689 - loss: 0.8716 - val_accuracy: 0.5788 - val_loss: 0.8461 - learning_rate: 1.0000e-05
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5651 - loss: 0.8585 - val_accuracy: 0.5788 - val_loss: 0.8385 - learning_rate: 1.0000e-05
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5698 - loss: 0.8379 - val_accuracy: 0.5813 - val_loss: 0.8350 - learning_rate: 1.0000e-05
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5818 - loss: 0.8373 - val_accuracy: 0.5775 - val_loss: 0.8257 - learning_rate: 1.0000e-05
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5889 - loss: 0.8281 - val_accuracy: 0.5825 - val_loss: 0.8233 - learning_rate: 1.0000e-05
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5929 - loss: 0.8339 - val_accuracy: 0.5750 - val_loss: 0.8309 - learning_rate: 1.0000e-05
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5707 - loss: 0.8411 - val_accuracy: 0.5925 - val_loss: 0.8041 - learning_rate: 1.0000e-05
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5944 - loss: 0.8250 - val_accuracy: 0.6037 - val_loss: 0.8095 - learning_rate: 1.0000e-05
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6036 - loss: 0.7928 - val_accuracy: 0.6162 - val_loss: 0.7861 - learning_rate: 1.0000e-05
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5965 - loss: 0.8083 - val_accuracy: 0.6087 - val_loss: 0.7852 - learning_rate: 1.0000e-05
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6079 - loss: 0.7823 - val_accuracy: 0.6025 - val_loss: 0.7837 - learning_rate: 1.0000e-05
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6017 - loss: 0.7920 - val_accuracy: 0.6263 - val_loss: 0.7761 - learning_rate: 1.0000e-05
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6274 - loss: 0.7750 - val_accuracy: 0.6313 - val_loss: 0.7638 - learning_rate: 1.0000e-05
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6090 - loss: 0.7958 - val_accuracy: 0.6463 - val_loss: 0.7606 - learning_rate: 1.0000e-05
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6140 - loss: 0.7848 - val_accuracy: 0.6450 - val_loss: 0.7552 - learning_rate: 1.0000e-05
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6307 - loss: 0.7623 - val_accuracy: 0.6587 - val_loss: 0.7482 - learning_rate: 1.0000e-05

# %%
#Evaluation + Confusion Matrix
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

results = {}

def evaluate(model, ds, name):
    y_true, y_pred = [], []

    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.append(y.numpy())
        y_pred.append(np.argmax(p, axis=1))

    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)

    acc = accuracy_score(y_true, y_pred)

    print(f"\n{name} Accuracy: {acc:.4f}")
    print(classification_report(y_true, y_pred, target_names=CLASSES))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(6,5))
    plt.imshow(cm)
    plt.title(f"{name} Confusion Matrix")
    plt.colorbar()
    plt.xticks(range(3), CLASSES)
    plt.yticks(range(3), CLASSES)

    for i in range(3):
        for j in range(3):
            plt.text(j, i, cm[i,j], ha="center", va="center")

    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    return acc

for name, model in models.items():
    results[name] = evaluate(model, test_ds, name)
# Out:
# SimCLR Accuracy: 0.9709
#               precision    recall  f1-score   support
#
#           AD       1.00      0.92      0.96       225
#           CN       0.91      0.99      0.95       288
#          MCI       1.00      0.98      0.99       518
#
#     accuracy                           0.97      1031
#    macro avg       0.97      0.96      0.97      1031
# weighted avg       0.97      0.97      0.97      1031
# SimSiam Accuracy: 0.9690
#               precision    recall  f1-score   support
#
#           AD       0.99      0.91      0.95       225
#           CN       0.98      0.97      0.97       288
#          MCI       0.96      0.99      0.98       518
#
#     accuracy                           0.97      1031
#    macro avg       0.97      0.96      0.97      1031
# weighted avg       0.97      0.97      0.97      1031
# BarlowTwins Accuracy: 0.6547
#               precision    recall  f1-score   support
#
#           AD       0.52      0.63      0.57       225
#           CN       0.61      0.38      0.47       288
#          MCI       0.73      0.82      0.77       518
#
#     accuracy                           0.65      1031
#    macro avg       0.62      0.61      0.60      1031
# weighted avg       0.65      0.65      0.64      1031

# %%
#Downstream Comparison Graph
plt.figure()
plt.bar(results.keys(), results.values())
plt.ylabel("Test Accuracy")
plt.title("Downstream Performance Comparison")
plt.ylim(0, 1)
plt.show()

# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# --- Collect a fixed subset of test images ONCE (same samples for all encoders) ---
MAX_BATCHES = 50  # increase if you want more points (may be slower)
Ximg_list, y_list = [], []

for i, (xb, yb) in enumerate(test_ds):
    if i >= MAX_BATCHES:
        break
    Ximg_list.append(xb.numpy())   # xb is already normalized in your pipeline
    y_list.append(yb.numpy())

Ximg = np.concatenate(Ximg_list, axis=0)
y    = np.concatenate(y_list, axis=0)

print("Using images:", Ximg.shape, "labels:", y.shape)

# --- Helper: get embeddings for a given encoder ---
def get_embeddings(encoder, Ximg, batch_size=64):
    feats = []
    for i in range(0, len(Ximg), batch_size):
        xb = Ximg[i:i+batch_size]
        f = encoder(xb, training=False)
        if len(f.shape) == 4:
            f = tf.reduce_mean(f, axis=[1,2])
        feats.append(f.numpy())
    return np.concatenate(feats, axis=0)

encoders = {
    "SimCLR": enc_simclr,
    "SimSiam": enc_simsam,
    "BarlowTwins": enc_barlow
}

# --- Run t-SNE for each encoder and plot ---
for name, enc in encoders.items():
    print(f"\nComputing embeddings for: {name}")
    Xfeat = get_embeddings(enc, Ximg, batch_size=64)
    print("Feature shape:", Xfeat.shape)

    # t-SNE (use same settings for fairness)
    tsne = TSNE(
        n_components=2,
        perplexity=30,
        random_state=SEED,
        init="pca",
        learning_rate="auto"
    )
    Z = tsne.fit_transform(Xfeat)

    plt.figure(figsize=(7,6))
    for ci, cls in enumerate(CLASSES):
        idx = (y == ci)
        plt.scatter(Z[idx, 0], Z[idx, 1], s=12, label=cls)
    plt.title(f"t-SNE (Test Embeddings) - {name}")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Using images: (1031, 224, 224, 3) labels: (1031,)
#
# Computing embeddings for: SimCLR
# Feature shape: (1031, 256)
# Computing embeddings for: SimSiam
# Feature shape: (1031, 256)
# Computing embeddings for: BarlowTwins
# Feature shape: (1031, 256)

# %%
#FULL ABLATION + STATS + GRADCAM (ALL 3 MODELS)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# -----------------------------
# 0) Small utilities
# -----------------------------
def plot_history(history, title):
    h = history.history

    plt.figure()
    plt.plot(h["loss"], label="Train")
    plt.plot(h["val_loss"], label="Validation")
    plt.title(f"{title} - Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(h["accuracy"], label="Train")
    plt.plot(h["val_accuracy"], label="Validation")
    plt.title(f"{title} - Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()


def unfreeze_last_layers(model, n=20):
    model.trainable = True
    if n is None:
        return
    for layer in model.layers[:-n]:
        layer.trainable = False


def get_optimizer(name="lars", lr=1e-3):
    name = name.lower()
    if name == "lars":
        try:
            import tensorflow_addons as tfa
            return tfa.optimizers.LARS(learning_rate=lr, momentum=0.9)
        except Exception as e:
            print(" LARS unavailable -> Adam fallback:", str(e)[:120], "...")
            return keras.optimizers.Adam(learning_rate=lr)
    elif name == "sgd":
        return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    else:
        return keras.optimizers.Adam(learning_rate=lr)


def build_downstream_model(encoder, trainable=False, dropout=0.3):
    encoder.trainable = trainable
    inp = keras.Input(shape=(*IMG_SIZE, 3))
    x = encoder(inp)
    # If spatial -> GAP (not your case now, but safe)
    if len(x.shape) == 4:
        x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    out = layers.Dense(len(CLASSES), activation="softmax")(x)
    return keras.Model(inp, out, name=f"downstream_{encoder.name}")


def eval_per_sample(model, ds):
    """Return y_true, y_pred, per-sample correctness vector (0/1), accuracy."""
    y_true, y_pred = [], []
    for xb, yb in ds:
        p = model.predict(xb, verbose=0)
        y_true.append(yb.numpy())
        y_pred.append(np.argmax(p, axis=1))
    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)
    correct = (y_pred == y_true).astype(np.int32)
    acc = correct.mean()
    return y_true, y_pred, correct, acc


# -----------------------------
# 1) IMPORTANT: clone encoders safely
#    so fine-tuning one does NOT change the others
# -----------------------------
def clone_model_with_weights(m):
    """Clones a keras model architecture + copies weights."""
    cm = keras.models.clone_model(m)
    cm.set_weights(m.get_weights())
    return cm


def make_encoder_smart(ssl_model):
    """Use layer before L2Normalization if present; else fallback to second last layer."""
    names = [l.name.lower() for l in ssl_model.layers]

    # pre-L2Normalization
    for i, n in enumerate(names):
        if "l2normal" in n or "l2_normal" in n:
            if i > 0:
                return keras.Model(ssl_model.input, ssl_model.layers[i-1].output,
                                  name=f"{ssl_model.name}_enc_preL2")

    # fallback
    return keras.Model(ssl_model.input, ssl_model.layers[-2].output,
                      name=f"{ssl_model.name}_enc_fallback")


# -----------------------------
# 2) Run ablation for all 3
# -----------------------------
AB_EPOCHS_FROZEN = 15
AB_EPOCHS_FT     = 10

HEAD_LR = 1e-3
FT_LR   = 1e-4
OPTIM   = "lars"

ssl_original = {
    "SimCLR": simclr_model,
    "SimSiam": simsam_model,
    "BarlowTwins": barlow_model
}

ablation_rows = []
ablation_models = {}  # store models for grad-cam later if needed

# We'll also keep per-sample correctness vectors to do paired t-test
correct_vectors = {}

for method, ssl_m in ssl_original.items():
    print("\n" + "="*70)
    print(f"ABLATION for: {method}")
    print("="*70)

    # clone SSL model (prevents weight contamination)
    ssl_clone = clone_model_with_weights(ssl_m)
    encoder = make_encoder_smart(ssl_clone)

    # ----- Frozen training -----
    frozen_model = build_downstream_model(encoder, trainable=False)
    frozen_model.compile(
        optimizer=get_optimizer(OPTIM, HEAD_LR),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    frozen_hist = frozen_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=AB_EPOCHS_FROZEN,
        callbacks=[
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True),
            keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5, min_lr=1e-6)
        ],
        verbose=1
    )

    plot_history(frozen_hist, f"{method} (Frozen Encoder)")

    y_true, y_pred, correct_frozen, acc_frozen = eval_per_sample(frozen_model, test_ds)
    print(f"{method} Frozen Test Acc = {acc_frozen:.4f}")

    # ----- Fine-tuning training -----
    # Unfreeze last N encoder layers
    unfreeze_last_layers(encoder, n=20)

    ft_model = build_downstream_model(encoder, trainable=True)
    ft_model.compile(
        optimizer=get_optimizer(OPTIM, FT_LR),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    ft_hist = ft_model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=AB_EPOCHS_FT,
        callbacks=[
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True),
            keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5, min_lr=1e-6)
        ],
        verbose=1
    )

    plot_history(ft_hist, f"{method} (Fine-tuned Encoder)")

    y_true2, y_pred2, correct_ft, acc_ft = eval_per_sample(ft_model, test_ds)
    print(f"{method} Fine-tuned Test Acc = {acc_ft:.4f}")

    # store
    correct_vectors[method] = {"frozen": correct_frozen, "finetuned": correct_ft}
    ablation_models[method] = {"frozen": frozen_model, "finetuned": ft_model}

    ablation_rows.append({
        "Method": method,
        "Frozen Acc": acc_frozen,
        "Fine-tuned Acc": acc_ft,
        "Δ Acc (FT-Frozen)": acc_ft - acc_frozen
    })

# -----------------------------
# 3) Ablation Table
# -----------------------------
ablation_df = pd.DataFrame(ablation_rows)
ablation_df = ablation_df.sort_values("Fine-tuned Acc", ascending=False).reset_index(drop=True)
display(ablation_df)
# Out:
# ======================================================================
# ABLATION for: SimCLR
# ======================================================================
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 89s 377ms/step - accuracy: 0.7066 - loss: 0.7079 - val_accuracy: 0.2988 - val_loss: 3.0020 - learning_rate: 0.0010
# Epoch 2/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.7889 - loss: 0.5181 - val_accuracy: 0.4087 - val_loss: 2.4908 - learning_rate: 0.0010
# Epoch 3/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8489 - loss: 0.3876 - val_accuracy: 0.5575 - val_loss: 1.0584 - learning_rate: 0.0010
# Epoch 4/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9039 - loss: 0.2723 - val_accuracy: 0.7250 - val_loss: 0.6105 - learning_rate: 0.0010
# Epoch 5/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9219 - loss: 0.2273 - val_accuracy: 0.6375 - val_loss: 1.3035 - learning_rate: 0.0010
# Epoch 6/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9331 - loss: 0.2037 - val_accuracy: 0.7625 - val_loss: 0.6974 - learning_rate: 0.0010
# Epoch 7/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9766 - loss: 0.0801 - val_accuracy: 0.9750 - val_loss: 0.1027 - learning_rate: 5.0000e-04
# Epoch 8/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9829 - loss: 0.0493 - val_accuracy: 0.9187 - val_loss: 0.2709 - learning_rate: 5.0000e-04
# Epoch 9/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9752 - loss: 0.0844 - val_accuracy: 0.9675 - val_loss: 0.0913 - learning_rate: 5.0000e-04
# Epoch 10/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9916 - loss: 0.0347 - val_accuracy: 0.9700 - val_loss: 0.0686 - learning_rate: 5.0000e-04
# Epoch 11/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9860 - loss: 0.0514 - val_accuracy: 0.9413 - val_loss: 0.2214 - learning_rate: 5.0000e-04
# Epoch 12/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9844 - loss: 0.0398 - val_accuracy: 0.9762 - val_loss: 0.0751 - learning_rate: 5.0000e-04
# Epoch 13/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9841 - loss: 0.0435 - val_accuracy: 0.9950 - val_loss: 0.0078 - learning_rate: 2.5000e-04
# Epoch 14/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9975 - val_loss: 0.0045 - learning_rate: 2.5000e-04
# Epoch 15/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9988 - loss: 0.0047 - val_accuracy: 0.9950 - val_loss: 0.0177 - learning_rate: 2.5000e-04
# SimCLR Frozen Test Acc = 0.9971
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.8265 - loss: 0.4466 - val_accuracy: 0.9925 - val_loss: 0.0240 - learning_rate: 1.0000e-04
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9960 - loss: 0.0310 - val_accuracy: 0.9950 - val_loss: 0.0107 - learning_rate: 1.0000e-04
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9932 - loss: 0.0288 - val_accuracy: 0.9950 - val_loss: 0.0128 - learning_rate: 1.0000e-04
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9959 - loss: 0.0196 - val_accuracy: 0.9975 - val_loss: 0.0062 - learning_rate: 1.0000e-04
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9913 - loss: 0.0401 - val_accuracy: 0.9912 - val_loss: 0.0195 - learning_rate: 1.0000e-04
# Epoch 6/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9944 - loss: 0.0331 - val_accuracy: 0.9987 - val_loss: 0.0059 - learning_rate: 1.0000e-04
# Epoch 7/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9925 - val_loss: 0.0267 - learning_rate: 1.0000e-04
# Epoch 8/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9962 - loss: 0.0164 - val_accuracy: 0.9912 - val_loss: 0.0221 - learning_rate: 1.0000e-04
# Epoch 9/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9939 - loss: 0.0333 - val_accuracy: 0.9975 - val_loss: 0.0045 - learning_rate: 5.0000e-05
# Epoch 10/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9972 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 6.7801e-04 - learning_rate: 5.0000e-05
# SimCLR Fine-tuned Test Acc = 0.9981
#
# ======================================================================
# ABLATION for: SimSiam
# ======================================================================
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 88s 374ms/step - accuracy: 0.6587 - loss: 0.8304 - val_accuracy: 0.4275 - val_loss: 1.1648 - learning_rate: 0.0010
# Epoch 2/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.7784 - loss: 0.5703 - val_accuracy: 0.5888 - val_loss: 0.8232 - learning_rate: 0.0010
# Epoch 3/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.8544 - loss: 0.3938 - val_accuracy: 0.6975 - val_loss: 0.7265 - learning_rate: 0.0010
# Epoch 4/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 165ms/step - accuracy: 0.8940 - loss: 0.2943 - val_accuracy: 0.7138 - val_loss: 0.9849 - learning_rate: 0.0010
# Epoch 5/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.8692 - loss: 0.3479 - val_accuracy: 0.6988 - val_loss: 0.7991 - learning_rate: 0.0010
# Epoch 6/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.8847 - loss: 0.3335 - val_accuracy: 0.9225 - val_loss: 0.2202 - learning_rate: 5.0000e-04
# Epoch 7/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9246 - loss: 0.1910 - val_accuracy: 0.7550 - val_loss: 0.7285 - learning_rate: 5.0000e-04
# Epoch 8/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9319 - loss: 0.2042 - val_accuracy: 0.9800 - val_loss: 0.0716 - learning_rate: 5.0000e-04
# Epoch 9/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9554 - loss: 0.1001 - val_accuracy: 0.5113 - val_loss: 1.7626 - learning_rate: 5.0000e-04
# Epoch 10/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9471 - loss: 0.1406 - val_accuracy: 0.9737 - val_loss: 0.0708 - learning_rate: 5.0000e-04
# Epoch 11/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9649 - loss: 0.0943 - val_accuracy: 0.7862 - val_loss: 0.5391 - learning_rate: 5.0000e-04
# Epoch 12/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9593 - loss: 0.0890 - val_accuracy: 0.9837 - val_loss: 0.0418 - learning_rate: 5.0000e-04
# Epoch 13/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9791 - loss: 0.0506 - val_accuracy: 0.9613 - val_loss: 0.1492 - learning_rate: 5.0000e-04
# Epoch 14/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9804 - loss: 0.0671 - val_accuracy: 0.9887 - val_loss: 0.0665 - learning_rate: 5.0000e-04
# Epoch 15/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9947 - loss: 0.0239 - val_accuracy: 0.9900 - val_loss: 0.0303 - learning_rate: 2.5000e-04
# SimSiam Frozen Test Acc = 0.9816
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 91s 380ms/step - accuracy: 0.7545 - loss: 0.6582 - val_accuracy: 0.9912 - val_loss: 0.0296 - learning_rate: 1.0000e-04
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9888 - loss: 0.0517 - val_accuracy: 0.9950 - val_loss: 0.0204 - learning_rate: 1.0000e-04
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9906 - loss: 0.0432 - val_accuracy: 0.9912 - val_loss: 0.0345 - learning_rate: 1.0000e-04
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9922 - loss: 0.0398 - val_accuracy: 0.9900 - val_loss: 0.0381 - learning_rate: 1.0000e-04
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.9972 - loss: 0.0158 - val_accuracy: 0.9925 - val_loss: 0.0261 - learning_rate: 5.0000e-05
# SimSiam Fine-tuned Test Acc = 0.9942
#
# ======================================================================
# ABLATION for: BarlowTwins
# ======================================================================
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 89s 382ms/step - accuracy: 0.4166 - loss: 1.1506 - val_accuracy: 0.4787 - val_loss: 1.0885 - learning_rate: 0.0010
# Epoch 2/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5025 - loss: 1.0365 - val_accuracy: 0.4900 - val_loss: 1.0568 - learning_rate: 0.0010
# Epoch 3/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4935 - loss: 1.0332 - val_accuracy: 0.4800 - val_loss: 1.0621 - learning_rate: 0.0010
# Epoch 4/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5042 - loss: 1.0491 - val_accuracy: 0.4750 - val_loss: 1.0431 - learning_rate: 0.0010
# Epoch 5/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.4962 - loss: 1.0376 - val_accuracy: 0.4812 - val_loss: 1.0464 - learning_rate: 0.0010
# Epoch 6/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4880 - loss: 1.0406 - val_accuracy: 0.4787 - val_loss: 1.0343 - learning_rate: 0.0010
# Epoch 7/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4822 - loss: 1.0369 - val_accuracy: 0.4863 - val_loss: 1.0513 - learning_rate: 0.0010
# Epoch 8/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4923 - loss: 1.0299 - val_accuracy: 0.4725 - val_loss: 1.0485 - learning_rate: 0.0010
# Epoch 9/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5022 - loss: 1.0204 - val_accuracy: 0.4863 - val_loss: 1.0908 - learning_rate: 5.0000e-04
# Epoch 10/15
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5003 - loss: 1.0170 - val_accuracy: 0.4913 - val_loss: 1.1356 - learning_rate: 5.0000e-04
# BarlowTwins Frozen Test Acc = 0.5024
#  LARS unavailable -> Adam fallback: No module named 'tensorflow_addons' ...
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 92s 381ms/step - accuracy: 0.4232 - loss: 1.2698 - val_accuracy: 0.4900 - val_loss: 1.0455 - learning_rate: 1.0000e-04
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4303 - loss: 1.2276 - val_accuracy: 0.4737 - val_loss: 1.0466 - learning_rate: 1.0000e-04
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.4395 - loss: 1.2201 - val_accuracy: 0.5075 - val_loss: 1.0256 - learning_rate: 1.0000e-04
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4477 - loss: 1.2002 - val_accuracy: 0.4925 - val_loss: 1.0501 - learning_rate: 1.0000e-04
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4506 - loss: 1.1625 - val_accuracy: 0.4900 - val_loss: 1.0499 - learning_rate: 1.0000e-04
# Epoch 6/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.4519 - loss: 1.1455 - val_accuracy: 0.5113 - val_loss: 1.0255 - learning_rate: 5.0000e-05
# Epoch 7/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.4447 - loss: 1.1703 - val_accuracy: 0.4863 - val_loss: 1.0398 - learning_rate: 5.0000e-05
# Epoch 8/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.4434 - loss: 1.1678 - val_accuracy: 0.5038 - val_loss: 1.0262 - learning_rate: 2.5000e-05
# Epoch 9/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 18s 166ms/step - accuracy: 0.4533 - loss: 1.1363 - val_accuracy: 0.4888 - val_loss: 1.0327 - learning_rate: 2.5000e-05
# BarlowTwins Fine-tuned Test Acc = 0.4908
#         Method  Frozen Acc  Fine-tuned Acc  Δ Acc (FT-Frozen)
# 0       SimCLR    0.997090        0.998060           0.000970
# 1      SimSiam    0.981571        0.994180           0.012609
# 2  BarlowTwins    0.502425        0.490786          -0.011639

# %%
from scipy.stats import ttest_rel

stats_rows = []
for method in correct_vectors.keys():
    a = correct_vectors[method]["frozen"]
    b = correct_vectors[method]["finetuned"]

    # paired t-test on per-sample correctness
    t_stat, p_val = ttest_rel(b, a)  # b (fine-tuned) vs a (frozen)

    stats_rows.append({
        "Method": method,
        "t-stat": float(t_stat),
        "p-value": float(p_val),
        "Significant (p<0.05)": (p_val < 0.05)
    })

stats_df = pd.DataFrame(stats_rows).sort_values("p-value")
display(stats_df)
# Out:
#         Method    t-stat   p-value  Significant (p<0.05)
# 1      SimSiam  2.993900  0.002820                  True
# 0       SimCLR  1.000000  0.317545                 False
# 2  BarlowTwins -0.889409  0.373991                 False

# %%
# Bar chart: Frozen vs Fine-tuned (grouped)
methods = ablation_df["Method"].tolist()
frozen_acc = ablation_df["Frozen Acc"].tolist()
ft_acc = ablation_df["Fine-tuned Acc"].tolist()
delta = ablation_df["Δ Acc (FT-Frozen)"].tolist()

x = np.arange(len(methods))
w = 0.35

plt.figure(figsize=(9,5))
plt.bar(x - w/2, frozen_acc, width=w, label="Frozen")
plt.bar(x + w/2, ft_acc, width=w, label="Fine-tuned")
plt.xticks(x, methods)
plt.ylim(0, 1.0)
plt.ylabel("Test Accuracy")
plt.title("Frozen vs Fine-tuned Downstream Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# Ablation graph: Delta accuracy
plt.figure(figsize=(8,4))
plt.bar(methods, delta)
plt.axhline(0, linewidth=1)
plt.ylabel("Δ Accuracy (Fine-tuned - Frozen)")
plt.title("Ablation Gain from Fine-tuning")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Data
# -----------------------------
methods = ablation_df["Method"].tolist()
frozen_acc = ablation_df["Frozen Acc"].values
finetuned_acc = ablation_df["Fine-tuned Acc"].values
overall_acc = np.maximum(frozen_acc, finetuned_acc)

x = np.arange(len(methods))
width = 0.22

# -----------------------------
# Figure
# -----------------------------
plt.figure(figsize=(9, 4.8))

plt.bar(
    x - width,
    frozen_acc,
    width=width,
    label="Frozen Encoder",
    hatch="//",
    edgecolor="black",
    linewidth=1
)

plt.bar(
    x,
    finetuned_acc,
    width=width,
    label="Fine-tuned Encoder",
    hatch="xx",
    edgecolor="black",
    linewidth=1
)

plt.bar(
    x + width,
    overall_acc,
    width=width,
    label="Overall Best",
    hatch="..",
    edgecolor="black",
    linewidth=1
)

# -----------------------------
# Axis & styling
# -----------------------------
plt.xticks(x, methods, fontsize=11)
plt.ylabel("Accuracy", fontsize=12)
plt.ylim(0.8, 1.0)   # tighten range for clarity (medical papers often do this)

plt.title(
    "Comparison of SSL Models: Ablation and Overall Performance",
    fontsize=13,
    pad=10
)

plt.legend(
    loc="upper center",
    bbox_to_anchor=(0.5, 1.15),
    ncol=3,
    frameon=False,
    fontsize=10
)

plt.grid(axis="y", linestyle="--", alpha=0.35)
plt.tight_layout()
plt.show()
